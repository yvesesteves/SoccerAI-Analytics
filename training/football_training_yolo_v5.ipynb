# %%
#library requirements
# !pip install ultralytics 
# !pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="QeveWeNZhzMIn5cMMe1I")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\yvesy\\OneDrive\\Área de Trabalho\\Projetos Pessoais\\Football_Analysis\\training\\football-players-detection-1'

# %%
import shutil #mover e copiar arquivos para pastas usando python

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
#epochs - quantidade de iteração de treinamento
#imgsz - tamanho da imagem

# feito no Google colab
